# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = [387, 243, 54, 45, 35]

# %%
plt.plot(y)

# %%
plt.plot(y, 'go-')

# %%
#plt.rcParams('font.family') = 'segoe UI Emoji'

Events = ["start", "Hellow\nWorld", "Datatypes", "Control Flow"]
weeks = np.arange(len(Events))
confidence = [22,32,12, 53]

plt.figure(figsize=(12, 5))
plt.plot(weeks, confidence, linewidth=2, markersize=9, markerfacecolor="green")
plt.show()

# %%
data = [614,65,97,546,245,31,358,465,5687,21]
players = ["a","b","c","d","e","f","g","h","i","j"]

plt.barh(players, data)
#plt.bar(players, data)
plt.show()

# %%
plt.bar(players, data)
plt.show()
